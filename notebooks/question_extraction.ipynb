# %% [markdown]
# # Question & Topic Extraction
#
# This notebook extracts questions and topics from PDFs and writes an aggregated CSV suitable for training an exam-question predictor.

# %%
import sys
import subprocess
# Install dependencies if needed (uncomment to run)
# subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--upgrade', 'pip'])
# subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'pdfminer.six', 'pandas', 'tqdm'])

# %%
# Run the extraction script on the provided PDF (adjust the filename if different)
import sys, subprocess, os
pdf_path = 'CSE 3rd year.pdf'
out_csv = 'data/training_dataset.csv'
script = os.path.join('scripts', 'extract_questions_from_pdf.py')
subprocess.check_call([sys.executable, script, pdf_path, '--out', out_csv])
print('Wrote:', out_csv)
